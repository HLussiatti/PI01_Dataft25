# %% [markdown]
# ## Flujo de Trabajo en NLP
#
# <img src="../_src/PLN_Flujo_Trabajo.jpg" height="300"><br>

# %%
import pandas as pd
import nltk
import re 
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk.tokenize import RegexpTokenizer

# %%
# Descargo los recursos necesarios
# nltk.download('punkt')
# nltk.download('averaged_perceptron_tagger')
# nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hernán\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Cargo la información de las reviews depuradas
df_reviews = pd.read_parquet('..\\datasets\\2. Depurado\\user_reviews_depurado.parquet')
#df_reviews = df_reviews.iloc[:1000] # para pruebas actodas.

# %% [markdown]
# - Se cargan las Stopwords en Inglés y se instancia el lemmatizer.

# %%
stopwords = nltk.corpus.stopwords.words('english') 
wordnet_lemmatizer = WordNetLemmatizer()

# %% [markdown]
# - Se elabora la función para mapeo de tipo de palabra para Lematización

# %%
# Las etiquetas refieren al tipo de palabra. Vamos a definir una función para traducir estas etiquetas a los valores de POS que entiende 'wordnet_lemmatizer'.
def get_wordnet_pos(word):
    
    """mapea los tipos de palabras cde nltk para la lematización"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}
    return tag_dict.get(tag, wordnet.NOUN)

# %% [markdown]
# - Se realiza el proceso de Tokenización, eliminación de Expresiones Regulares y Lematización

# %%
def process_review(review):
    if pd.isna(review):
        return []  # Review vacío
    
    # Limpieza y procesamiento - Si la review no es nula

    # Elimino URLs
    text = re.sub(r'http\S+', '', text)
    
    # Elimino todo lo que no sean letras y convertir a minúsculas
    review = re.sub("[^a-zA-Z]", " ", str(review)).lower()

    # Tokeniza la review depues de sacar las condiciones regulares que le pasamos
    tokenizer = RegexpTokenizer(r'\w+')
    review = tokenizer.tokenize(review)
    
    # Elimina las stopwords 
    review = [word for word in review if word not in stopwords]
    # Lematización
    review = [wordnet_lemmatizer.lemmatize(word, get_wordnet_pos(word)) for word in review]
    
    return review


# Aplicar la función de procesamiento a cada reseña
df_reviews["processed_reviews"] = df_reviews["review"].apply(process_review)

# %% [markdown]
# - Utiizamos la Librería TEXTBLOB para la categorización de las Reviews.

# %%
from textblob import TextBlob

# %%
# Función para clasificar el sentimiento
def classify_sentiment(review):
    # Unir la lista de palabras en una cadena de texto
    review_text = " ".join(review)

    if not review_text:
        return 'Neutro' # Si no hay review, asignar "Neutro"
    
    # Crear un objeto TextBlob
    blob = TextBlob(review_text)
    # Obtener el sentimiento
    polarity = blob.sentiment.polarity

    # Clasificación del sentimiento
    if polarity > 0:
        return 'Positivo'
    elif polarity < 0:
        return 'Negativo'
    else:
        return 'Neutro'

# Aplicar la función a la columna "review"
df_reviews['sentiment'] = df_reviews['processed_reviews'].apply(classify_sentiment)

# Aplicar el valor necesario
df_reviews['sentiment_value'] = df_reviews['sentiment'].map({'Negativo': '0', 'Neutro': '1', 'Positivo':'2'})

# Guardo el resultado para su uso posterior
df_reviews.to_parquet('..\\datasets\\2. Depurado\\user_reviews_NLP_TextBlob.parquet', index=False)

# %% [markdown]
# - Breve análisis de resultados

# %%
# Cargo la información de las reviews
df_reviews = pd.read_parquet('..\\datasets\\2. Depurado\\user_reviews_NLP_TextBlob.parquet')

# %%
df_reviews[df_reviews['recommend'] == False].head(10)
# Out:
#                    user_id                                           user_url  \
# 48       76561198043472122  http://steamcommunity.com/profiles/76561198043...
# 62       76561198066046412  http://steamcommunity.com/profiles/76561198066...
# 68       76561198070565427  http://steamcommunity.com/profiles/76561198070...
# 84                 boydeer               http://steamcommunity.com/id/boydeer
# 122            sandwiches1           http://steamcommunity.com/id/sandwiches1
# 132  iamthekingofbrowntown  http://steamcommunity.com/id/iamthekingofbrown...
# 156      76561198010674657  http://steamcommunity.com/profiles/76561198010...
# 183              Nozomikat             http://steamcommunity.com/id/Nozomikat
# 186             xfluttersx            http://steamcommunity.com/id/xfluttersx
# 193          ii_voltage_ii         http://steamcommunity.com/id/ii_voltage_ii
#
#      item_id                      posted  \
# 48     33440   Posted December 19, 2014.
# 62    359320   Posted December 28, 2015.
# 68       570       Posted June 27, 2014.
# 84    383080     Posted August 24, 2015.
# 122   417860   Posted November 23, 2015.
# 132   344760  Posted September 12, 2015.
# 156   377160            Posted March 27.
# 183   437220           Posted August 19.
# 186   202530        Posted September 14.
# 193   253710       Posted June 29, 2014.
#
#                                             helpful  recommend  \
# 48    1 of 3 people (33%) found this review helpful      False
# 62    4 of 5 people (80%) found this review helpful      False
# 68                                   No ratings yet      False
# 84    4 of 7 people (57%) found this review helpful      False
# 122                                  No ratings yet      False
# 132   3 of 4 people (75%) found this review helpful      False
# 156   3 of 4 people (75%) found this review helpful      False
# 183  7 of 13 people (54%) found this review helpful      False
# 186  1 of 1 people (100%) found this review helpful      False
# 193   1 of 2 people (50%) found this review helpful      False
#
#                                 funny  \
# 48
# 62
# 68
# 84
# 122
# 132
# 156
# 183  1 person found this review funny
# 186
# 193
#
#                                                 review  \
# 48                              This Game Doesn't Work
# 62   ♥♥♥♥♥ charged me 80 now its 15 dollars, got bo...
# 68                                                  w,
# 84                                เกมเเดกเงินดีๆนี้เอง
# 122                                    Emily is a thot
# 132  Spent 3 days making a base. Man teleported in ...
# 156  Where do I begin...I trusted you Bethesda. Fro...
# 183  Very harsh to new players. Combat system is st...
# 186  This has got to be worse than sonic 06'!I play...
# 193  Is this game actually Free to Play ? I don't t...
#
#                                      processed_reviews sentiment  \
# 48                                        [game, work]  Negativo
# 62                 [charge, dollar, get, boring, hour]  Negativo
# 68                                                 [w]    Neutro
# 84                                                  []    Neutro
# 122                                      [emily, thot]    Neutro
# 132  [spent, day, make, base, man, teleport, base, ...  Negativo
# 156  [begin, trust, bethesda, time, spent, fo, neve...  Positivo
# 183  [harsh, new, player, combat, system, strange, ...  Negativo
# 186  [get, bad, sonic, played, many, sonic, game, k...  Negativo
# 193  [game, actually, free, play, think, hunt, one,...  Negativo
#
#     sentiment_value
# 48                0
# 62                0
# 68                1
# 84                1
# 122               1
# 132               0
# 156               2
# 183               0
# 186               0
# 193               0

# %%
# Ver el contenido completo de la primera reseña
print(df_reviews['review'].iloc[156])
# Ver el contenido completo de la primera reseña
print(df_reviews['processed_reviews'].iloc[156])
# Out:
# Where do I begin...I trusted you Bethesda. From all the time I spent with FO3... I never could have imagined this garbage is what you'd spew up from the depths of whatever 'creative' hell it came from. I thought you would learn from what Obsidian did with New Vegas, more depth - more REALISM.The map is smaller than Skyrim, Todd. Not in length, or width, but in the sense that the little things are missing. The special touch and charm that is just on the cusp of every corner you'd turn in the previous fallout titles is missing... The environment feels hollow, too vibrant, too smooth. It's not the same Fallout theme I grew to crave and felt wonder at. You traded something original, something special, from those wonky shooter mechanics to the skill bar and karma system, for what? better FPS mechanics and a more 'console-friendly' interaction system? I would suggest that all digital copies are wiped and the physical copies piled into a garbage dump like Atari did when E.T. the Extra Terrestrial failed... but I digress...This game should serve as a warning to those who find themselves with an IP as significant as the Fallout Universe. It's like they say - "IF IT AIN'T BROKE, DON'T FIX IT!" Do yourself a favour and buy Fallout: New Vegas, instead of this $80 squirming feeling of regret and hopelessness.
# ['begin' 'trust' 'bethesda' 'time' 'spent' 'fo' 'never' 'could' 'imagine'
#  'garbage' 'spew' 'depth' 'whatever' 'creative' 'hell' 'come' 'thought'
#  'would' 'learn' 'obsidian' 'new' 'vega' 'depth' 'realism' 'map' 'small'
#  'skyrim' 'todd' 'length' 'width' 'sense' 'little' 'thing' 'miss'
#  'special' 'touch' 'charm' 'cusp' 'every' 'corner' 'turn' 'previous'
#  'fallout' 'title' 'miss' 'environment' 'feel' 'hollow' 'vibrant' 'smooth'
#  'fallout' 'theme' 'grow' 'crave' 'felt' 'wonder' 'trade' 'something'
#  'original' 'something' 'special' 'wonky' 'shooter' 'mechanic' 'skill'
#  'bar' 'karma' 'system' 'well' 'fps' 'mechanic' 'console' 'friendly'
#  'interaction' 'system' 'would' 'suggest' 'digital' 'copy' 'wipe'
#  'physical' 'copy' 'pile' 'garbage' 'dump' 'like' 'atari' 'e' 'extra'
#  'terrestrial' 'fail' 'digress' 'game' 'serve' 'warn' 'find' 'ip'
#  'significant' 'fallout' 'universe' 'like' 'say' 'broke' 'fix' 'favour'
#  'buy' 'fallout' 'new' 'vega' 'instead' 'squirm' 'feel' 'regret'
#  'hopelessness']
